# %% [markdown]
# <a href="https://colab.research.google.com/github/skillsoftware455-dev/nextjs-ai-chatbot/blob/main/GenAi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("*!*Hello From Second File*!*")
# Out:
# *!*Hello From Second File*!*
